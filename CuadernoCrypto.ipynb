# %%
import pandas as pd, matplotlib, numpy as np
from scipy.io import arff
from scipy.stats import pearsonr
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import scale
import matplotlib.pyplot as plt
from matplotlib import style
import statsmodels.api as sm
import seaborn as sns
from datetime import date, timedelta
import plotly.express as px
import plotly.graph_objects as go
import re

# %%
df=pd.read_csv("cripto/1000_cryptos.csv")

df['Symbol'].nunique()
#Hay mil criptos.
# Out:
# 1000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1119099 entries, 0 to 1119098
# Data columns (total 9 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   Unnamed: 0  1119099 non-null  int64
#  1   Date        1119099 non-null  object
#  2   Open        1110104 non-null  float64
#  3   High        1110104 non-null  float64
#  4   Low         1110104 non-null  float64
#  5   Close       1110104 non-null  float64
#  6   Adj Close   1110104 non-null  float64
#  7   Volume      1110104 non-null  float64
#  8   Symbol      1119099 non-null  object
# dtypes: float64(6), int64(1), object(2)
# memory usage: 76.8+ MB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0       0
# Date             0
# Open          8995
# High          8995
# Low           8995
# Close         8995
# Adj Close     8995
# Volume        8995
# Symbol           0
# dtype: int64

# %%
df_vol_sorted = df.sort_values(by = 'Volume',ascending = False)
top_100 = list(df_vol_sorted['Symbol'].unique()[:50])
len(top_100)

df_BTC = df[df['Symbol'] == 'BTC-USD']

df_vol_100 = df[df['Symbol'].isin(top_100)]


df_ETH = df[df['Symbol'] == 'ETH-USD']



fig = px.line(
    df_BTC,
    x="Date",
    y="Open",
    color="Symbol"
)

# %%
graphic = px.line(
    df_BTC,
    x="Date",
    y="Open",
    color="Symbol"
)
